# %%
import pandas as pd
import os

data_folder = '../../../data/AdTalking'

# %% [markdown]
# ## Training Sample

# %%
file = 'train_sample.csv'
file_path = os.path.join(data_folder, file)

df = pd.read_csv(file_path, parse_dates=['click_time'])
df
# Out:
#            ip  app  device  os  channel          click_time attributed_time  \
# 0       87540   12       1  13      497 2017-11-07 09:30:38             NaN
# 1      105560   25       1  17      259 2017-11-07 13:40:27             NaN
# 2      101424   12       1  19      212 2017-11-07 18:05:24             NaN
# 3       94584   13       1  13      477 2017-11-07 04:58:08             NaN
# 4       68413   12       1   1      178 2017-11-09 09:00:09             NaN
# ...       ...  ...     ...  ..      ...                 ...             ...
# 99995  124883   11       1  19      122 2017-11-09 13:25:41             NaN
# 99996   85150    9       1  13      244 2017-11-07 11:25:43             NaN
# 99997   18839    3       1  13       19 2017-11-08 11:38:42             NaN
# 99998  114276   15       1  12      245 2017-11-08 17:55:21             NaN
# 99999  119349   14       1  15      401 2017-11-07 14:32:27             NaN
#
#        is_attributed
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 99995              0
# 99996              0
# 99997              0
# 99998              0
# 99999              0
#
# [100000 rows x 8 columns]

# %%
df.is_attributed.value_counts()
# Out:
# 0    99773
# 1      227
# Name: is_attributed, dtype: int64

# %%
df.is_attributed.value_counts()[1] / df.shape[0]
# Out:
# 0.00227

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ip               100000 non-null  int64
#  1   app              100000 non-null  int64
#  2   device           100000 non-null  int64
#  3   os               100000 non-null  int64
#  4   channel          100000 non-null  int64
#  5   click_time       100000 non-null  datetime64[ns]
#  6   attributed_time  227 non-null     object
#  7   is_attributed    100000 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 6.1+ MB

# %% [markdown]
# ## Training Total
# - 데이터 로딩에 약 2분 걸림
# - 총 열의 갯수: 184,903,890
# - Fraud 비율은 약 0.2% 정도 임

# %%
# %%time
file = 'train.csv'
file_path = os.path.join(data_folder, file)

df_t = pd.read_csv(file_path, parse_dates=['click_time'])
df_t
# Out:
# CPU times: user 1min 28s, sys: 11.9 s, total: 1min 40s
# Wall time: 1min 56s
#                ip  app  device  os  channel          click_time  \
# 0           83230    3       1  13      379 2017-11-06 14:32:21
# 1           17357    3       1  19      379 2017-11-06 14:33:34
# 2           35810    3       1  13      379 2017-11-06 14:34:12
# 3           45745   14       1  13      478 2017-11-06 14:34:52
# 4          161007    3       1  13      379 2017-11-06 14:35:08
# ...           ...  ...     ...  ..      ...                 ...
# 184903885  121312   12       1  10      340 2017-11-09 16:00:00
# 184903886   46894    3       1  19      211 2017-11-09 16:00:00
# 184903887  320126    1       1  13      274 2017-11-09 16:00:00
# 184903888  189286   12       1  37      259 2017-11-09 16:00:00
# 184903889  106485   11       1  19      137 2017-11-09 16:00:00
#
#           attributed_time  is_attributed
# 0                     NaN              0
# 1                     NaN              0
# 2                     NaN              0
# 3                     NaN              0
# 4                     NaN              0
# ...                   ...            ...
# 184903885             NaN              0
# 184903886             NaN              0
# 184903887             NaN              0
# 184903888             NaN              0
# 184903889             NaN              0
#
# [184903890 rows x 8 columns]

# %%
df_t.is_attributed.value_counts()
# Out:
# 0    184447044
# 1       456846
# Name: is_attributed, dtype: int64

# %%
df_t.is_attributed.value_counts()[1] / df_t.shape[0]
# Out:
# 0.002470721410998979

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184903890 entries, 0 to 184903889
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ip               int64
#  1   app              int64
#  2   device           int64
#  3   os               int64
#  4   channel          int64
#  5   click_time       datetime64[ns]
#  6   attributed_time  object
#  7   is_attributed    int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 11.0+ GB

# %% [markdown]
# ## Test
# - 데이터 로딩에 약 1분 걸림
# - 총 열의 갯수: 184,903,890
# - Fraud 비율은 약 0.2% 정도 임

# %%
file = 'test.csv'
file_path = os.path.join(data_folder, file)

df_test = pd.read_csv(file_path)
df_test
# Out:
#           click_id      ip  app  device  os  channel           click_time
# 0                0    5744    9       1   3      107  2017-11-10 04:00:00
# 1                1  119901    9       1   3      466  2017-11-10 04:00:00
# 2                2   72287   21       1  19      128  2017-11-10 04:00:00
# 3                3   78477   15       1  13      111  2017-11-10 04:00:00
# 4                4  123080   12       1  13      328  2017-11-10 04:00:00
# ...            ...     ...  ...     ...  ..      ...                  ...
# 18790464  18790464   99442    9       1  13      127  2017-11-10 15:00:00
# 18790465  18790465   88046   23       1  37      153  2017-11-10 15:00:00
# 18790466  18790467   81398   18       1  17      265  2017-11-10 15:00:00
# 18790467  18790466  123236   27       1  13      122  2017-11-10 15:00:00
# 18790468  18790468   73516   12       2  27      265  2017-11-10 15:00:00
#
# [18790469 rows x 7 columns]

# %% [markdown]
# ## 데이타 Resampling (훈련, 테스트)

# %%
print("min time: ", df_t.click_time.min())
print("max time: ", df_t.click_time.max())
# Out:
# min time:  2017-11-06 14:32:21
# max time:  2017-11-09 16:00:00

# %%
df_temp = df_t.sample(n=2000000)

# %%
def split_data_by_time(df, target_col, label_col, total_samples, split_rate, fraud_rate, train_end, test_start, verbose=False):
    '''
    시간 관점으로 번반부튼 훈련, 후반부는 테스트 데이터로 해서 샘블링 함.
    '''
    
    # 훈련 데이터 셋
    train_df = df[df[target_col] <= train_end]   
    train_num = int(total_samples * (1 - split_rate))    
    train_sample = train_df.sample(n = train_num, random_state=100)        

    print("train sample shape: ", train_sample.shape)
    print("train min time: ", train_sample.click_time.min())
    print("train max time: ", train_sample.click_time.max())
    print("Train fraud ratio: ", round(train_sample[label_col].value_counts()[1] / train_sample.shape[0],5))


    # 테스트 데이터 셋    
    test_df = df[df[target_col] >= test_start]    
    test_num = int(total_samples * (split_rate))    
    test_sample = test_df.sample(n = test_num, random_state=100)    
    

    print("\ntest sample shape: ", test_sample.shape)    
    print("test min time: ", test_sample.click_time.min())
    print("test max time: ", test_sample.click_time.max())
    print("Fest ratio: ", test_sample[label_col].value_counts()[1] / test_sample.shape[0])
    print("Test fraud ratio: ", round(test_sample[label_col].value_counts()[1] / test_sample.shape[0],5))    
    
    
    return train_sample, test_sample
    
train_df, test_df = split_data_by_time(
                       df=df_temp, 
                       target_col='click_time', 
                       label_col = 'is_attributed',
                       total_samples=10000, 
                       split_rate=0.1, 
                       fraud_rate = 0.02,
                       train_end='2017-11-08 23:59', 
                       test_start='2017-11-09 00:00',    
                       verbose = True,
                  )
# Out:
# train sample shape:  (9000, 8)
# train min time:  2017-11-06 16:00:45
# train max time:  2017-11-08 23:58:45
# Train fraud ratio:  0.002
#
# test sample shape:  (1000, 8)
# test min time:  2017-11-09 00:00:30
# test max time:  2017-11-09 15:58:38
# Fest ratio:  0.002
# Test fraud ratio:  0.002

# %%
os.makedirs(exist_ok=)
